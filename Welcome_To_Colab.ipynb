# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshitkadian2005/beggining/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
'''The Positive SumConcept: for loop, if statement, accumulator variable.Task: Given a mixed list of 1. integers: numbers = [10, -5, 20, -10, 30, -2]. Write a loop to calculate the sum of only the positive numbers.'''

a= [10, -5, 20, -10, 30, -2]
c=0
for i in range (len(a)) :
  if a[i] >0:
    c +=a[i]
  else:
    print("below zwro")
print(c)
# Out:
# below zwro
# below zwro
# below zwro
# 60

# %%
''' The Vowel CounterConcept: String iteration, in operator, counters.Task: Ask the  user for a sentence. 2. Write a script that counts the total number of vowels (a, e, i, o, u) in that sentence, ignoring case (A and a are both vowels)'''
a =str (input ( "enter a string"))
b=0
for i in range(len(a)):
  if a[i] in  "eiouEIOU":
    b+=1
  else :
    print("fuck")
print(b)
# Out:
# enter a stringasfa
# fuck
# fuck
# fuck
# fuck
# 0

# %%
a=["Python", "Java", "C++", "Go"]
b=[]
for i in range(len(a)) :
  b.insert(0,a[i])

print(b)
# Out:
# ['Go', 'C++', 'Java', 'Python']

# %%
a=int(input('entera no'))
for i in range(2,a):
  print('*' *i)
# Out:
# entera no7
# **
# ***
# ****
# *****
# ******

# %%
raw_data = [1, 2, 2, 3, 4, 4, 4, 5]
b=set(raw_data)
print(list(b))
# Out:
# [1, 2, 3, 4, 5]

# %%
'''2. Even/Odd List Sorter This problem involves iterating over a list and making decisions. The Task: Given the list numbers = [1, 5, 22, 9, 14, 3, 4, 88, 7]. Create two new empty lists, evens and odds. Loop through the numbers list. If a number is even, add it to the evens list. If a number is odd, add it to the odds list. Finally, print both the evens and odds lists.'''


num = [1, 5, 22, 9, 14, 3, 4, 88, 7]
even_list=[]
odd_list=[]
for i in range (len(num)):
  if i %2==0:
    even_list.append(num[i])
  else :
    odd_list.append(num[i])
print("oddno",odd_list)
print("even no",even_list)
# Out:
# oddno [5, 9, 3, 88]
# even no [1, 22, 14, 4, 7]
